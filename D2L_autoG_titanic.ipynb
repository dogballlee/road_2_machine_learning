# %%
from autogluon.tabular import TabularDataset,TabularPredictor
#训练
path = r'D:\kaggle\titanic'
train_data = TabularDataset(path + '\\train.csv')
id,label = 'PassengerId','Survived'
predictor = TabularPredictor(label=label).fit(train_data.drop(columns=[id]))
# Out:
# Loaded data from: D:\kaggle\titanic\train.csv | Columns = 12 / 12 | Rows = 891 -> 891
# No path specified. Models will be saved in: "AutogluonModels/ag-20210601_053235\"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210601_053235\"
# AutoGluon Version:  0.2.0
# Train Data Rows:    891
# Train Data Columns: 10
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    2420.77 MB
# 	Train Data (Original)  Memory Usage: 0.31 MB (0.0% of available memory)
# ...

# %%
import pandas as pd
#测试
test_data = TabularDataset(path + '\\test.csv')
preds = predictor.predict(test_data.drop(columns=[id]))
submission = pd.DataFrame({id:test_data[id], label:preds})
submission.to_csv('autogluon_submission.csv', index=False)
# Out:
# D:\anaconda3\envs\d2l-zh\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Loaded data from: D:\kaggle\titanic\test.csv | Columns = 11 / 11 | Rows = 418 -> 418
